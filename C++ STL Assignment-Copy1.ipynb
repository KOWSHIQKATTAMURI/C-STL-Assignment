// %% [markdown]
// # Question No 1

// %% [markdown]
// Return the researcher's h-index from an array of integer references, where references[i] is the number of references a researcher obtained for their ith work. Wikipedia's description of the h-index states that it is the highest value of h at which a researcher has published at least h publications, each of which has been referenced at least h times.

// %% [raw]
// Sample Input 1: references = [3, 0, 6, 1, 5]
// Output: 3
// Explanation: [3,0,6,1,5] means the researcher has 5 papers in total and each of them has received 3, 0, 6, 1, 5 references respectively. Since the researcher has 3 papers (3, 6, 5) with at least 3 references each and the remaining two (0, 1) with no more than 3 references each, his/her h-index is 3.

// %% [raw]
// Sample Input 2: references = [1, 3, 1]
// Output: 1
// Explanation: [1, 3, 1] means the researcher has 3 papers in total and each of them has received 1, 3, 1 references respectively. Since the researcher has 2 papers (1, 1) with at least 1 references each and the remaining paper (3) has only 3 references, his/her h-index is 1.

// %% [raw]
// Sample Input 3: references = [4, 2, 7, 8, 1, 10, 32, 55]
// Output: 5
// Explanation: [4, 2, 7, 8, 1, 10, 32, 55] means the researcher has 8 papers in total and each of them has received 4, 2, 7, 8, 1, 10, 32, 55 references respectively. Since the researcher has 5 papers (7, 8, 10, 32, 55) with at least 5 references each and the remaining three (4, 2, 1) with no more than 5 references each, his/her h-index is 5.

// %% [markdown]
// Hint: Try figuring out the possible values of h-index by organizing the values of
//            the given references array.

// %% [markdown]
// # You need not write the whole code, just write the code to the function below:

// %%
int h_index(vector<int>& references){ 
    
}

// %% [markdown]
// # Question No 2

// %% [markdown]
// Return a vector of k most frequent elements from the integer array nums. The input to the following problem is an integer array ‘nums’ and an integer ‘k’. You may return the answer in any order. It is guaranteed that the answer is unique.

// %% [raw]
// Sample Input 1: nums = [1, 1, 1, 2, 2, 3], k = 2
// Output: [1, 2]
// Explanation: There are 3 1’s, 2 2’s, and one 3 in the given array nums. So the top 2 most frequent elements are 1, 2, so the answer is [1, 2].

// %% [raw]
// Sample Input 2: nums = [1], k = 1
// Output: [1]
// Explanation: There is only one 1, so the answer is [1].

// %% [raw]
// Sample Input 3: nums = [4,4,3,3,3,2,2,1,1,6,7,7,7,8,8,9,10,9,10], k = 2
// Output: [3, 7]
// Explanation: There are 2 1’s, 2 2’s, 3 3’s, 2 4’s, one 6, 3 7’s, 2 8’s, 2 9’s, and 2 10’s  in the given array nums. So the top 2 most frequent elements are 3, 7, so the answer is [3, 7].

// %% [markdown]
// # You need not write the whole code, just write the code to the function below

// %%
vector<int> topKFrequent(vector<int>& nums, int k){ 
    
}

// %% [markdown]
// # (Optional) Question No 3

// %% [markdown]
// You are given a string s of just uppercase English letters.
// You can perform some actions on this string such as removing all instances of "AB" or "CD" from s in one operation.
// Return the shortest length of the resultant string you can get.
// It should be noted that the string concatenates after the substring is removed and may result in brand-new "AB" or "CD" substrings.

// %% [raw]
// Sample Input 1: s = "ABFCACDB"
// Output: 2
// Explanation: We can do the following operations:
// Remove the substring "ABFCACDB", so s = "FCACDB".
// Remove the substring "FCACDB", so s = "FCAB".
// Remove the substring "FCAB", so s = "FC".
// So the resulting length of the string is 2. It can be shown that it is the minimum length that we can obtain.

// %% [raw]
// Sample Input 2: s = "ABCDBEAFCBEBDACBDYZRS"
// Output: 17
// Explanation: We can do the following operations:
// Remove the substring "ABCDBEAFCBEBDACBDYZRS",
// so s = "CDBEAFCBEBDACBDYZRS".
// Remove the substring "CDBEAFCBEBDACBDYZRS",
// so s = "BEAFCBEBDACBDYZRS".
// We cannot do any more operations on this resultant string. So the resulting length of the string is 17.

// %% [raw]
// Sample Input 3: s = "ACBBD"
// Output: 5
// Explanation: We cannot do any operations on the string so the length remains the same.

// %% [markdown]
// # You need not write the whole code, just write the code to the function below

// %%
int min_length(string s){ 
    
}
